# %% [markdown]
# <!-- # Title here {-} -->

# %% [markdown]
# Per Halvorsen   \
# [pmhalvor@uio.no](mailto:pmhalvor@uio.no) \
# GEO4460

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Introduction
#
#
# In this paper, we will look into ....
# The data used to build this analysis comes from the [INSERT BIG LINK HERE]() Geological Survey of Norway (NGU), and the software used is ArcGIS Pro.
#
# Topics we will explore:
#
# - Distribution of cultivated fields in a specified municipality
# - Conflicting groundwater resources and cultivated land/buildings/rivers (why rivers?)
# - Which elevations do marine areas exist?
# - Which land cover type (soil class) dominates the selected municipality?
# - Which sediments primarily dominates cultivated fields?
# - What sediment type is preferable as groundwater resources?

# %% [markdown]
# # Data

# %% [markdown]
# ## Sub section

# %% [markdown]
# # Methods

# %% [markdown]
# # Results (/Analysis)

# %% [markdown]
# # Discussion (/Analysis)

# %% [markdown]
# # Conclusion/Summary

# %% [markdown]
# # References
